# %% [markdown]
# <a href="https://colab.research.google.com/github/giselalsouto/LC-complexidade/blob/main/complexidade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Calcula-la complexidade textual
#
# ## 0. Organización
#
# 1. Textos a analizar
# 2. Preparar o sistema para traballar con arquivos
# 3. Instalar e Cargar (*importar*) unha libraría de Procesamento da Linguaxe Natural (PLN)
# 4. Descargar módulos de idiomas e activar tuberías de procesamento.
# 5. Empregar a libraría para as análises requiridas e exposición de resultados.

# %% [markdown]
# ## 1. Textos
#
# Temos dous textos a analizar, un en galego (texto-gl.txt) e outro en castelán (texto-es.txt).
#
# ## 2. Preparar o sistema para traballar con arquivos
#
# Para iso, temos que carga-lo módulo adicado a funcións do sistema operativo (os).

# %%
import os

# %% [markdown]
# Para non repetir unha e outra vez os nomes dos arquivos que imos empregar, imos xerar dúas variables con eles:

# %%
file_gl_path = '/content/drive/MyDrive/Colab Notebooks/Lingüística Computacional/Complexidade de textos/texto-gl.txt'
file_es_path =  '/content/drive/MyDrive/Colab Notebooks/Lingüística Computacional/Complexidade de textos/texto-es.txt'

# %% [markdown]
# Imos enviar o texto dos arquivos a cadanseu arquivo, para poder traballar máis doadamente (dado que non son textos especialmente extensos).
#
# Ao facelo, comprobaremos que existan con `os.path.exists`.

# %%
if (os.path.exists(file_gl_path)):
  with (open(file_gl_path,'r')) as file_gl:
    texto_gl = file_gl.read()

# %% [markdown]
# O anterior foi para o texto en galego.
#
# Agora, para o texto en castelán:

# %%
if (os.path.exists(file_es_path)):
  with (open(file_es_path,'r')) as file_es:
    texto_es = file_es.read()

# %% [markdown]
# ## 3. Instalar e Cargar (*importar*) unha libraría de Procesamento da Linguaxe Natural (PLN)
#
# Cargaremos unha libraría que nos evite o traballo de ter que programar as accións para prepara-lo texto, etiqueta-lo, etc.
#
# No noso caso, empregaremos *stanza*.
#
# O primeiro que temos que facer, é descargar *stanza*
#
# Neste sistema (colab) esto faise iniciando cunha marca de exclamación de peche ( `!` ) e logo o comando.
#
# O comando que empregaremos é `pip`, que é un programa para instalar, descargando da rede, os módulos que precisemos.
#
# O comando quedaría así:

# %%
# !pip install stanza
# Out:
# Requirement already satisfied: stanza in /usr/local/lib/python3.11/dist-packages (1.10.1)
# Requirement already satisfied: emoji in /usr/local/lib/python3.11/dist-packages (from stanza) (2.14.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from stanza) (2.0.2)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (5.29.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from stanza) (2.32.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from stanza) (3.4.2)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from stanza) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (4.13.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.3.0->stanza) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.3.0->stanza) (3.0.2)

# %% [markdown]
# Agora temos que importar *stanza* para poder empregalo.

# %%
import stanza

# %% [markdown]
# ## 4. Descargar módulos de idiomas e activar tuberías de procesamento.
#
# Unha vez instalado *stanza* imos descargar os idiomas a empregar.
# No noso caso, serán o galego (*gl*) e o castelán (*es*).

# %%
stanza.download('gl')
stanza.download('es')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Downloading default packages for language: gl (Galician) ...
# INFO:stanza:File exists: /root/stanza_resources/gl/default.zip
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Downloading default packages for language: es (Spanish) ...
# INFO:stanza:File exists: /root/stanza_resources/es/default.zip
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources

# %% [markdown]
# Agora debemos abrir o que se chama un pipeline (tubería, en inglés), que é o que nos permite empregar os procesadores para o texto en linguaxe natural.
#
# No noso caso, abriremos dúas pipelines (ou tuberías), cada unha etiquetada co idioma que serve, polo que teremos: `pipe_gl`e `pipe_es`.

# %%
pipe_gl = stanza.Pipeline('gl')
pipe_es = stanza.Pipeline('es')
# Out:
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Loading these models for language: gl (Galician):
# ============================
# | Processor | Package      |
# ----------------------------
# | tokenize  | ctg          |
# | mwt       | ctg          |
# | pos       | ctg_nocharlm |
# | lemma     | ctg_nocharlm |
# | depparse  | ctg_nocharlm |
# ============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Loading these models for language: es (Spanish):
# ====================================
# | Processor    | Package           |
# ------------------------------------
# | tokenize     | combined          |
# | mwt          | combined          |
# | pos          | combined_charlm   |
# | lemma        | combined_nocharlm |
# | constituency | combined_charlm   |
# | depparse     | combined_charlm   |
# | sentiment    | tass2020_charlm   |
# | ner          | conll02           |
# ====================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: constituency
# INFO:stanza:Loading: depparse
# INFO:stanza:Loading: sentiment
# INFO:stanza:Loading: ner
# INFO:stanza:Done loading processors!

# %% [markdown]
# ## 5. Empregar a libraría para as análises requiridas e exposición de resultados.
#
# Unha vez abertas as tuberías que levan os datos os procesadores automáticos da linguaxe, imos ver de comezar a procesar o texto.
#
# De feito, para iso, só temos que empregar as tuberías que xa fixemos.
#
# Mais antes, imos preparar os tipo *Document* para cada idioma:
#
# *doc_gl* e *doc_es*

# %%
doc_gl = pipe_gl(texto_gl)
doc_es = pipe_es(texto_es)

# %% [markdown]
# ### 5.1. Análises requiridas
# #### 5.1.1. Preparación
#
# Primeiro, imos definir algunhas das variables que imos precisar para facer o exercicio

# %%
#dicionario léxico baleiro (galego)
dic_lexico = {}

#dicionario de dificultade de lectura baleiro (galego)
dic_dific = {}

#dicionario léxico baleiro en castelán
dic_lexico_es = {}

#dicionario de dificultade de lectura baleiro (castelán)
dic_dific_es = {}

## variables galego
#variable para o número de frases do texto en galego
f_gl = -1

#lista pf_gl para o número de palabras por frase en galego
pf_gl = []
#variable p_gl para o número total de palabras en galego
p_gl = 0
#variable para o número de letras por palabra en galego
l_gl = 0
#número de caracteres do texto en galego
c_txt_gl = 0

## variables castelán
#variable para o número de frases do texto en castelán
f_es = -1

#lista pf_es para o número de palabras por frase en castelán
pf_es = []

#lista p para o número de palabras por frase en castelán
p_es = []

#variable para o número de letras por palabra en castelán
l_es = 0

#número de caracteres do texto (en castelán)
c_txt_es = 0

# %% [markdown]
# Aquí faremos o procesamento do texto en galego

# %%
#PROCESAMENTO DE TEXTO EN GALEGO

for frase_gl in doc_gl.sentences:
  f_gl += 1
  pf_gl.insert(f_gl,0)
  #pf_gl[f_gl]=len(doc_gl.sentences[f_gl].words)
  print("número de palabras da frase ", f_gl, ": ", pf_gl[f_gl])
  for palabra_gl in frase_gl.words:
     if (palabra_gl.upos != 'PUNCT'):
      pf_gl[f_gl] += 1
     print(palabra_gl.text)
     ##visualiza por pantalla a información:
     print("Posición: ", palabra_gl.id," \t Palabra: ", palabra_gl.text, "\t Lema: ", palabra_gl.lemma, "\t Etiqueta: ", palabra_gl.upos,"\t Etiqueta xpos:", palabra_gl.xpos,  "\t Head: ", palabra_gl.head,"\t Feat: ", palabra_gl.feats, "\t Dep: ", palabra_gl.deprel,sep=" ")
     # If the item is already in dictionary, increase its count
     if palabra_gl.upos in dic_lexico:
         dic_lexico[palabra_gl.upos] += 1
     # If the item is not in dictionary, add it with a count of 1
     else:
         dic_lexico[palabra_gl.upos] = 1


     upos_act = palabra_gl.upos
     if upos_act == 'NOUN' or upos_act == 'ADJ' or upos_act == 'PRON':
      if palabra_gl.upos in dic_dific:
        dic_dific[palabra_gl.upos] += 1
      # If the item is not in dictionary, add it with a count of 1
      else:
          dic_dific[palabra_gl.upos] = 1

      c_txt_gl += len(palabra_gl.text)


#Xeración de Resultados
print(pf_gl)
num_tipos = len(dic_lexico)
num_tipos_dific_gl = len(dic_dific)
print("Dicionario léxico en galego, número de tipos: ", num_tipos)
print("Dicionario léxico en galego: ", dic_lexico)
p_gl = sum(pf_gl)
total_f_gl = f_gl + 1
lmf_gl = p_gl / total_f_gl
print("Total de palabras do texto en galego: ", p_gl)
print("Número de caracteres totais do texto en galego: ", len(texto_gl),"\n")
nmc_gl = c_txt_gl / p_gl
ttr_gl = num_tipos / p_gl
proc = "en proceso"
dific_gl = num_tipos_dific_gl / num_tipos
# Out:
# número de palabras da frase  0 :  0
# Non
# Posición:  1  	 Palabra:  Non 	 Lema:  non 	 Etiqueta:  PART 	 Etiqueta xpos: RN 	 Head:  2 	 Feat:  None 	 Dep:  advmod
# habería
# Posición:  2  	 Palabra:  habería 	 Lema:  haber 	 Etiqueta:  VERB 	 Etiqueta xpos: VMIC3S0 	 Head:  0 	 Feat:  None 	 Dep:  root
# rapaz
# Posición:  3  	 Palabra:  rapaz 	 Lema:  rapaz 	 Etiqueta:  NOUN 	 Etiqueta xpos: NCMS000 	 Head:  2 	 Feat:  None 	 Dep:  obj
# coma
# Posición:  4  	 Palabra:  coma 	 Lema:  coma 	 Etiqueta:  SCONJ 	 Etiqueta xpos: CS 	 Head:  2 	 Feat:  None 	 Dep:  mark
# il
# Posición:  5  	 Palabra:  il 	 Lema:  il 	 Etiqueta:  PROPN 	 Etiqueta xpos: NP00000 	 Head:  2 	 Feat:  None 	 Dep:  nsubj
# se
# Posición:  6  	 Palabra:  se 	 Lema:  se 	 Etiqueta:  PRON 	 Etiqueta xpos: PP3CN000 	 Head:  10 	 Feat:  None 	 Dep:  nsubj
# non
# Posición:  7  	 Palabra:  non 	 Lema:  non 	 Etiqueta:  PART 	 Etiqueta xpos: RN 	 Head:  10 	 Feat:  None 	 Dep:  advmod
# fora
# Posición:  8  	 Palabra:  fora 	 Lema:  ser 	 Etiqueta:  AUX 	 Etiqueta xpos: VMIM1S0 	 Head:  10 	 Feat:  None 	 Dep:  cop
# tan
# Posición:  9  	 Palabra:  tan 	 Lema:  tan 	 Etiqueta:  ADV 	 Etiqueta xpos: RG 	 Head:  10 	 Feat:  None 	 Dep:  advmod
# xogantín
# Posición:  10  	 Palabra:  xogantín 	 Lema:  xogantín 	 Etiqueta:  ADJ 	 Etiqueta xpos: AQ0CP0 	 Head:  2 	 Feat:  None 	 Dep:  ccomp
# .
# Posición:  11  	 Palabra:  . 	 Lema:  . 	 Etiqueta:  PUNCT 	 Etiqueta xpos: Fp 	 Head:  2 	 Feat:  None 	 Dep:  punct
# número de palabras da frase  1 :  0
# Xogaba
# Posición:  1  	 Palabra:  Xogaba 	 Lema:  xogar 	 Etiqueta:  VERB 	 Etiqueta xpos: VMII1S0 	 Head:  0 	 Feat:  None 	 Dep:  root
# hastra
# Posición:  2  	 Palabra:  hastra 	 Lema:  hastrar 	 Etiqueta:  VERB 	 Etiqueta xpos: VMIP3S0 	 Head:  1 	 Feat:  None 	 Dep:  obj
# a
# Posición:  3  	 Palabra:  a 	 Lema:  o 	 Etiqueta:  DET 	 Etiqueta xpos: DA0FS0 	 Head:  4 	 Feat:  None 	 Dep:  det
# camisa
# Posición:  4  	 Palabra:  camisa 	 Lema:  camisa 	 Etiqueta:  NOUN 	 Etiqueta xpos: NCFS000 	 Head:  2 	 Feat:  None 	 Dep:  obj
# .
# Posición:  5  	 Palabra:  . 	 Lema:  . 	 Etiqueta:  PUNCT 	 Etiqueta xpos: Fp 	 Head:  1 	 Feat:  None 	 Dep:  punct
# número de palabras da frase
	 Etiqueta:  ADV 	 Etiqueta xpos: RG 	 Head:  3 	 Feat:  None 	 Dep:  advmod
# estaba
# Posición:  2  	 Palabra:  estaba 	 Lema:  estar 	 Etiqueta:  AUX 	 Etiqueta xpos: VMII3S0 	 Head:  3 	 Feat:  None 	 Dep:  cop
# en
# Posición:  3  	 Palabra:  en 	 Lema:  en 	 Etiqueta:  ADP 	 Etiqueta xpos: SPS00 	 Head:  0 	 Feat:  None 	 Dep:  root
# tratos
# Posición:  4  	 Palabra:  tratos 	 Lema:  trato 	 Etiqueta:  NOUN 	 Etiqueta xpos: NCMP000 	 Head:  3 	 Feat:  None 	 Dep:  nmod
# con
# Posición:  5  	 Palabra:  con 	 Lema:  con 	 Etiqueta:  ADP 	 Etiqueta xpos: SPS00 	 Head:  7 	 Feat:  None 	 Dep:  case
# un
# Posición:  6  	 Palabra:  un 	 Lema:  un 	 Etiqueta:  DET 	 Etiqueta xpos: DI0MS0 	 Head:  7 	 Feat:  None 	 Dep:  det
# xateiro
# Posición:  7  	 Palabra:  xateiro 	 Lema:  xateiro 	 Etiqueta:  NOUN 	 Etiqueta xpos: NCMS000 	 Head:  3 	 Feat:  None 	 Dep:  nmod
# de
# Posición:  8  	 Palabra:  de 	 Lema:  de 	 Etiqueta:  ADP 	 Etiqueta xpos: SPS00 	 Head:  10 	 Feat:  None 	 Dep:  case
# a
# Posición:  9  	 Palabra:  a 	 Lema:  o 	 Etiqueta:  DET 	 Etiqueta xpos: DA0FS0 	 Head:  10 	 Feat:  None 	 Dep:  det
# Hermida
# Posición:  10  	 Palabra:  Hermida 	 Lema:  hermida 	 Etiqueta:  PROPN 	 Etiqueta xpos: NP00000 	 Head:  7 	 Feat:  None 	 Dep:  nmod
# pra
# Posición:  11  	 Palabra:  pra 	 Lema:  prar 	 Etiqueta:  VERB 	 Etiqueta xpos: VMIP3S0 	 Head:  3 	 Feat:  None 	 Dep:  ccomp
# mercar
# Posición:  12  	 Palabra:  mercar 	 Lema:  mercar 	 Etiqueta:  VERB 	 Etiqueta xpos: VMN0000 	 Head:  11 	 Feat:  None 	 Dep:  obj
# un
# Posición:  13  	 Palabra:  un 	 Lema:  un 	 Etiqueta:  DET 	 Etiqueta xpos: DI0MS0 	 Head:  14 	 Feat:  None 	 Dep:  det
# cabalo
# Posición:  14  	 Palabra:  cabalo 	 Lema:  cabalo 	 Etiqueta:  NOUN 	 Etiqueta xpos: NCMS000 	 Head:  12 	 Feat:  None 	 Dep:  obj
# .
# Posición:  15  	 Palabra:  . 	 Lema:  . 	 Etiqueta:  PUNCT 	 Etiqueta xpos: Fp 	 Head:  3 	 Feat:  None 	 Dep:  punct
# número de palabras da frase  10 :  0
# Querían
# Posición:  1  	 Palabra:  Querían 	 Lema:  querer 	 Etiqueta:  VERB 	 Etiqueta xpos: VMII3P0 	 Head:  0 	 Feat:  None 	 Dep:  root
# o
# Posición:  2  	 Palabra:  o 	 Lema:  o 	 Etiqueta:  PRON 	 Etiqueta xpos: PP3MSA00 	 Head:  1 	 Feat:  None 	 Dep:  obj
# moito
# Posición:  3  	 Palabra:  moito 	 Lema:  moito 	 Etiqueta:  ADV 	 Etiqueta xpos: RG 	 Head:  1 	 Feat:  None 	 Dep:  case
# en
# Posición:  4  	 Palabra:  en 	 Lema:  en 	 Etiqueta:  ADP 	 Etiqueta xpos: SPS00 	 Head:  7 	 Feat:  None 	 Dep:  case
# todos
# Posición:  5  	 Palabra:  todos 	 Lema:  todo 	 Etiqueta:  DET 	 Etiqueta xpos: DI0MP0 	 Head:  6 	 Feat:  None 	 Dep:  det
# os
# Posición:  6  	 Palabra:  os 	 Lema:  o 	 Etiqueta:  DET 	 Etiqueta xpos: DA0MP0 	 Head:  7 	 Feat:  None 	 Dep:  det
# sitios
# Posición:  7  	 Palabra:  sitios 	 Lema:  sitio 	 Etiqueta:  NOUN 	 Etiqueta xpos: NCMP000 	 Head:  1 	 Feat:  None 	 Dep:  obl
# onde
# Posición:  8  	 Palabra:  onde 	 Lema:  onde 	 Etiqueta:  PRON 	 Etiqueta xpos: PR0CN000 	 Head:  9 	 Feat:  None 	 Dep:  nsubj
# capaba
# Posición:  9  	 Palabra:  capaba 	 Lema:  capar 	 Etiqueta:  VERB 	 Etiqueta xpos: VMSI3S0 	 Head:  7 	 Feat:  None 	 Dep:  ccomp
# ranchos
# Posición:  10  	 Palabra:  ranchos 	 Lema:  rancho 	 Etiqueta:  NOUN 	 Etiqueta xpos: NCMP000 	 Head:
	 Etiqueta:  NOUN 	 Etiqueta xpos: NCFS000 	 Head:  1 	 Feat:  None 	 Dep:  nmod
# .
# Posición:  5  	 Palabra:  . 	 Lema:  . 	 Etiqueta:  PUNCT 	 Etiqueta xpos: Fp 	 Head:  1 	 Feat:  None 	 Dep:  punct
# número de palabras da frase  16 :  0
# Tempo
# Posición:  1  	 Palabra:  Tempo 	 Lema:  tempo 	 Etiqueta:  NOUN 	 Etiqueta xpos: NCMS000 	 Head:  0 	 Feat:  None 	 Dep:  root
# de
# Posición:  2  	 Palabra:  de 	 Lema:  de 	 Etiqueta:  ADP 	 Etiqueta xpos: SPS00 	 Head:  3 	 Feat:  None 	 Dep:  case
# fartura
# Posición:  3  	 Palabra:  fartura 	 Lema:  fartura 	 Etiqueta:  NOUN 	 Etiqueta xpos: NCFS000 	 Head:  1 	 Feat:  None 	 Dep:  nmod
# .
# Posición:  4  	 Palabra:  . 	 Lema:  . 	 Etiqueta:  PUNCT 	 Etiqueta xpos: Fp 	 Head:  1 	 Feat:  None 	 Dep:  punct
# número de palabras da frase  17 :  0
# Xantara
# Posición:  1  	 Palabra:  Xantara 	 Lema:  xantar 	 Etiqueta:  VERB 	 Etiqueta xpos: VMI03S0 	 Head:  0 	 Feat:  None 	 Dep:  root
# aquil
# Posición:  2  	 Palabra:  aquil 	 Lema:  aquil 	 Etiqueta:  ADJ 	 Etiqueta xpos: AQ0MS0 	 Head:  3 	 Feat:  None 	 Dep:  amod
# día
# Posición:  3  	 Palabra:  día 	 Lema:  día 	 Etiqueta:  NOUN 	 Etiqueta xpos: NCMS000 	 Head:  1 	 Feat:  None 	 Dep:  case
# en
# Posición:  4  	 Palabra:  en 	 Lema:  en 	 Etiqueta:  ADP 	 Etiqueta xpos: SPS00 	 Head:  5 	 Feat:  None 	 Dep:  case
# cas
# Posición:  5  	 Palabra:  cas 	 Lema:  cas 	 Etiqueta:  NOUN 	 Etiqueta xpos: NCFP000 	 Head:  1 	 Feat:  None 	 Dep:  obl
# de
# Posición:  6  	 Palabra:  de 	 Lema:  de 	 Etiqueta:  ADP 	 Etiqueta xpos: SPS00 	 Head:  8 	 Feat:  None 	 Dep:  case
# o
# Posición:  7  	 Palabra:  o 	 Lema:  o 	 Etiqueta:  DET 	 Etiqueta xpos: DA0MS0 	 Head:  8 	 Feat:  None 	 Dep:  det
# Rulo
# Posición:  8  	 Palabra:  Rulo 	 Lema:  rulo 	 Etiqueta:  NOUN 	 Etiqueta xpos: NCMS000 	 Head:  5 	 Feat:  None 	 Dep:  nmod
# .
# Posición:  9  	 Palabra:  . 	 Lema:  . 	 Etiqueta:  PUNCT 	 Etiqueta xpos: Fp 	 Head:  1 	 Feat:  None 	 Dep:  punct
# número de palabras da frase  18 :  0
# Encheran
# Posición:  1  	 Palabra:  Encheran 	 Lema:  encherar 	 Etiqueta:  VERB 	 Etiqueta xpos: VMIP3P0 	 Head:  0 	 Feat:  None 	 Dep:  root
# se
# Posición:  2  	 Palabra:  se 	 Lema:  se 	 Etiqueta:  PRON 	 Etiqueta xpos: PP3CN000 	 Head:  1 	 Feat:  None 	 Dep:  dep
# de
# Posición:  3  	 Palabra:  de 	 Lema:  de 	 Etiqueta:  ADP 	 Etiqueta xpos: SPS00 	 Head:  4 	 Feat:  None 	 Dep:  case
# néboa
# Posición:  4  	 Palabra:  néboa 	 Lema:  néboa 	 Etiqueta:  NOUN 	 Etiqueta xpos: NCFS000 	 Head:  1 	 Feat:  None 	 Dep:  obl
# os
# Posición:  5  	 Palabra:  os 	 Lema:  o 	 Etiqueta:  DET 	 Etiqueta xpos: DA0MP0 	 Head:  6 	 Feat:  None 	 Dep:  det
# cavorcos
# Posición:  6  	 Palabra:  cavorcos 	 Lema:  cavorco 	 Etiqueta:  NOUN 	 Etiqueta xpos: NCMP000 	 Head:  1 	 Feat:  None 	 Dep:  nsubj
# .
# Posición:  7  	 Palabra:  . 	 Lema:  . 	 Etiqueta:  PUNCT 	 Etiqueta xpos: Fp 	 Head:  1 	 Feat:  None 	 Dep:  punct
# número de palabras da frase  19 :  0
# Non
# Posición:  1  	 Palabra:  Non 	 Lema:  non 	 Etiqueta:  PART 	 Etiqueta xpos: RN 	 Head:  3 	 Feat:  None 	 Dep:  advmod
# se
# Posición:  2  	 Palabra:  se 	 Lema:  se 	 Etiqueta:  PRON 	 Etiqueta xpos: PP3CN000 	 Head:  3 	 Feat:  None 	 Dep:  dep
# vía
# Posición:  3  	 Palabra:  vía 	 Lema:  vía 	 Etiqueta:  NOUN 	 Etiqueta xpos: NCFS000 	 Head:  10 	 Feat:  None 	 Dep:  obj
# un
# Posición:  4  	 Palabra:  un 	 Lema:  un 	 Etiqueta:  DET 	 Etiqueta xpos: DI0MS0 	 Head:  5 	 Feat:  None 	 Dep:  det
# burro
# Posición:  5  	 Palabra:  burro 	 Lema:  burro 	 Etiqueta:  NOUN 	 Etiqueta xpos: NCMS000 	 Head:  3 	 Feat:  None 	 Dep:  nmod
# a
# Posición:  6  	 Palabra:  a 	 Lema:  a 	 Etiqueta:  ADP 	 Etiqueta xpos: SPS00 	 Head:  7 	 Feat:  None 	 Dep:  case
# tres
# Posición:  7  	 Palabra:  tres 	 Lema:  tres 	 Etiqueta:  NOUN 	 Etiqueta xpos: NCMS000 	 Head:  5 	 Feat:  None 	 Dep:  nmod
# pasos
# Posición:  8  	 Palabra:  pasos 	 Lema:  paso 	 Etiqueta:  NOUN 	 Etiqueta xpos: NCMP000 	 Head:  7 	 Feat:  None 	 Dep:  nmod
# ,
# Posición:  9  	 Palabra:  , 	 Lema:  , 	 Etiqueta:  PUNCT 	 Etiqueta xpos: Fc 	 Head:  10 	 Feat:  None 	 Dep:  punct
# dispensando
# Posición:  10  	 Palabra:  dispensando 	 Lema:  dispensar 	 Etiqueta:  VERB 	 Etiqueta xpos: VMG0000 	 Head:  0 	 Feat:  None 	 Dep:  root
# ...
# Posición:  11  	 Palabra:  ... 	 Lema:  ... 	 Etiqueta:  PUNCT 	 Etiqueta xpos: Fs 	 Head:  10 	 Feat:  None 	 Dep:  punct
# número de palabras da frase  20 :  0
# O
# Posición:  1  	 Palabra:  O 	 Lema:  o 	 Etiqueta:  DET 	 Etiqueta xpos: DA0MS0 	 Head:  2 	 Feat:  None 	 Dep:  det
# Rulo
# Posición:  2  	 Palabra:  Rulo 	 Lema:  rulo 	 Etiqueta:  NOUN 	 Etiqueta xpos: NCMS000 	 Head:  3 	 Feat:  None 	 Dep:  nsubj
# díxolle
# Posición:  3  	 Palabra:  díxolle 	 Lema:  díxoller 	 Etiqueta:  VERB 	 Etiqueta xpos: VMIS1S0 	 Head:  0 	 Feat:  None 	 Dep:  root
# que
# Posición:  4  	 Palabra:  que 	 Lema:  que 	 Etiqueta:  SCONJ 	 Etiqueta xpos: CS 	 Head:  5 	 Feat:  None 	 Dep:  mark
# pasara
# Posición:  5  	 Palabra:  pasara 	 Lema:  pasar 	 Etiqueta:  VERB 	 Etiqueta xpos: VMIM1S0 	 Head:  3 	 Feat:  None 	 Dep:  obj
# a
# Posición:  6  	 Palabra:  a 	 Lema:  o 	 Etiqueta:  DET 	 Etiqueta xpos: DA0FS0 	 Head:  7 	 Feat:  None 	 Dep:  det
# noite
# Posición:  7  	 Palabra:  noite 	 Lema:  noite 	 Etiqueta:  NOUN 	 Etiqueta xpos: NCFS000 	 Head:  5 	 Feat:  None 	 Dep:  obj
# en
# Posición:  8  	 Palabra:  en 	 Lema:  en 	 Etiqueta:  ADP 	 Etiqueta xpos: SPS00 	 Head:  11 	 Feat:  None 	 Dep:  case
# a
# Posición:  9  	 Palabra:  a 	 Lema:  o 	 Etiqueta:  DET 	 Etiqueta xpos: DA0FS0 	 Head:  11 	 Feat:  None 	 Dep:  det
# súa
# Posición:  10  	 Palabra:  súa 	 Lema:  seu 	 Etiqueta:  DET 	 Etiqueta xpos: DP3FS0 	 Head:  11 	 Feat:  None 	 Dep:  det
# casa
# Posición:  11  	 Palabra:  casa 	 Lema:  casa 	 Etiqueta:  NOUN 	 Etiqueta xpos: NCFS000 	 Head:  5 	 Feat:  None 	 Dep:  obl
# .
# Posición:  12  	 Palabra:  . 	 Lema:  . 	 Etiqueta:  PUNCT 	 Etiqueta xpos: Fp 	 Head:  3 	 Feat:  None 	 Dep:  punct
# [10, 4, 17, 16, 12, 17, 10, 10, 11, 14, 17, 5, 10, 10, 12, 3, 3, 8, 6, 9, 11]
# Dicionario léxico en galego, número de tipos:  13
# Dicionario léxico en galego:  {'PART': 5, 'VERB': 33, 'NOUN': 62, 'SCONJ': 6, 'PROPN': 4, 'PRON': 15, 'AUX': 5, 'ADV': 10, 'ADJ': 5, 'PUNCT': 33, 'DET': 35, 'ADP': 30, 'CCONJ': 5}
# Total de palabras do texto en galego:  215
# Número de caracteres totais do texto en galego:  1056

# %% [markdown]
# Velaquí temos os resultados do procesamento do texto en galego

# %%
#Resultados a análises pedidas
print("RESULTADOS: \n")
print("Lonxitude media de frases (texto en galego):", lmf_gl )
print("Diversidade lexical (TTR): ", ttr_gl)
print("Lonxitude media das palabras (texto en galego): ", nmc_gl)
print("Índice de dificultade de lectura (texto en galego)", dific_gl)
# Out:
# RESULTADOS:
#
# Lonxitude media de frases (texto en galego): 10.238095238095237
# Diversidade lexical (TTR):  0.06046511627906977
# Lonxitude media das palabras (texto en galego):  1.7023255813953488
# Índice de dificultade de lectura (texto en galego) 0.23076923076923078

# %% [markdown]
# Aquí faremos o procesamento do texto en castelán

# %%
#TRATAMENTO DE TEXTO EN CASTELÁN

for frase_es in doc_es.sentences:
  f_es += 1
  print('f_es: ',f_es)
  pf_es.insert(f_es,0)
  #print(doc_es.sentences)
  #pf_es[f_es]=len(doc_es.sentences[f_es].words)
  print("número de palabras da frase ", f_es, ": ", pf_es[f_es])
  for palabra_es in frase_es.words:
    if (palabra_es.upos != 'PUNCT'):
     pf_es[f_es] += 1
    print(palabra_es.text)
    ##visualiza por pantalla a información:
    print("Posición: ", palabra_es.id," \t Palabra: ", palabra_es.text, "\t Lema: ", palabra_es.lemma, "\t Etiqueta: ", palabra_es.upos,"\t Etiqueta xpos:", palabra_es.xpos,  "\t Head: ", palabra_es.head,"\t Feat: ", palabra_es.feats, "\t Dep: ", palabra_es.deprel,sep=" ")
    # If the item is already in dictionary, increase its count
    if palabra_es.upos in dic_lexico_es:
        dic_lexico_es[palabra_es.upos] += 1
    # If the item is not in dictionary, add it with a count of 1
    else:
        dic_lexico_es[palabra_es.upos] = 1

    upos_act_es = palabra_es.upos
    if (upos_act_es == 'ADV' or upos_act_es == 'ADJ' or upos_act_es == 'PRON'):
      if upos_act_es in dic_dific_es:
        dic_dific_es[upos_act_es] += 1
      # If the item is not in dictionary, add it with a count of 1
      else:
          dic_dific_es[palabra_gl.upos] = 1

    c_txt_gl += len(palabra_gl.text)


print(pf_es)
num_tipos_es = len(dic_lexico_es)
num_tipos_dific_es = len(dic_dific_es)
print("Dicionario léxico en castelán, número de tipos: ", num_tipos)
print("Dicionario léxico en castelán: ", dic_lexico_es)
p_es = sum(pf_es)
total_f_es = f_es + 1
lmf_es = p_es / total_f_es
c_txt_es = len(texto_es)
print("Total de palabras do texto en castelán: ", p_es)
print("Número de caracteres totais do texto en castelán: ", len(texto_es))
nmc_es = c_txt_es / p_es
ttr_es = num_tipos / p_es
dific_es = num_tipos_dific_es / num_tipos_es

# Comparar resultados
# Out:
# f_es:  0
# número de palabras da frase  0 :  0
# El
# Posición:  1  	 Palabra:  El 	 Lema:  el 	 Etiqueta:  DET 	 Etiqueta xpos: da0ms0 	 Head:  2 	 Feat:  Definite=Def|Gender=Masc|Number=Sing|PronType=Art 	 Dep:  det
# cambio
# Posición:  2  	 Palabra:  cambio 	 Lema:  cambio 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncms000 	 Head:  5 	 Feat:  Gender=Masc|Number=Sing 	 Dep:  nsubj
# de
# Posición:  3  	 Palabra:  de 	 Lema:  de 	 Etiqueta:  ADP 	 Etiqueta xpos: sps00 	 Head:  4 	 Feat:  None 	 Dep:  case
# condiciones
# Posición:  4  	 Palabra:  condiciones 	 Lema:  condición 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncfp000 	 Head:  2 	 Feat:  Gender=Fem|Number=Plur 	 Dep:  nmod
# produce
# Posición:  5  	 Palabra:  produce 	 Lema:  producir 	 Etiqueta:  VERB 	 Etiqueta xpos: vmip3s0 	 Head:  0 	 Feat:  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin 	 Dep:  root
# un
# Posición:  6  	 Palabra:  un 	 Lema:  uno 	 Etiqueta:  DET 	 Etiqueta xpos: di0ms0 	 Head:  7 	 Feat:  Definite=Ind|Gender=Masc|Number=Sing|PronType=Art 	 Dep:  det
# efecto
# Posición:  7  	 Palabra:  efecto 	 Lema:  efecto 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncms000 	 Head:  5 	 Feat:  Gender=Masc|Number=Sing 	 Dep:  obj
# hereditario
# Posición:  8  	 Palabra:  hereditario 	 Lema:  hereditario 	 Etiqueta:  ADJ 	 Etiqueta xpos: aq0ms0 	 Head:  7 	 Feat:  Gender=Masc|Number=Sing 	 Dep:  amod
# ,
# Posición:  9  	 Palabra:  , 	 Lema:  , 	 Etiqueta:  PUNCT 	 Etiqueta xpos: fc 	 Head:  13 	 Feat:  PunctType=Comm 	 Dep:  punct
# como
# Posición:  10  	 Palabra:  como 	 Lema:  como 	 Etiqueta:  SCONJ 	 Etiqueta xpos: cs 	 Head:  13 	 Feat:  None 	 Dep:  mark
# en
# Posición:  11  	 Palabra:  en 	 Lema:  en 	 Etiqueta:  ADP 	 Etiqueta xpos: sps00 	 Head:  13 	 Feat:  None 	 Dep:  case
# la
# Posición:  12  	 Palabra:  la 	 Lema:  el 	 Etiqueta:  DET 	 Etiqueta xpos: da0fs0 	 Head:  13 	 Feat:  Definite=Def|Gender=Fem|Number=Sing|PronType=Art 	 Dep:  det
# época
# Posición:  13  	 Palabra:  época 	 Lema:  época 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncfs000 	 Head:  5 	 Feat:  Gender=Fem|Number=Sing 	 Dep:  obl
# de
# Posición:  14  	 Palabra:  de 	 Lema:  de 	 Etiqueta:  ADP 	 Etiqueta xpos: sps00 	 Head:  15 	 Feat:  None 	 Dep:  mark
# florecer
# Posición:  15  	 Palabra:  florecer 	 Lema:  florecer 	 Etiqueta:  VERB 	 Etiqueta xpos: vmn0000 	 Head:  13 	 Feat:  VerbForm=Inf 	 Dep:  acl
# las
# Posición:  16  	 Palabra:  las 	 Lema:  el 	 Etiqueta:  DET 	 Etiqueta xpos: da0fp0 	 Head:  17 	 Feat:  Definite=Def|Gender=Fem|Number=Plur|PronType=Art 	 Dep:  det
# plantas
# Posición:  17  	 Palabra:  plantas 	 Lema:  planta 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncfp000 	 Head:  15 	 Feat:  Gender=Fem|Number=Plur 	 Dep:  obj
# cuando
# Posición:  18  	 Palabra:  cuando 	 Lema:  cuando 	 Etiqueta:  SCONJ 	 Etiqueta xpos: cs 	 Head:  21 	 Feat:  None 	 Dep:  mark
# se
# Posición:  19  	 Palabra:  se 	 Lema:  él 	 Etiqueta:  PRON 	 Etiqueta xpos: p0000000 	 Head:  21 	 Feat:  Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes 	 Dep:  expl:pv
# las
# Posición:  20  	 Palabra:  las 	 Lema:  él 	 Etiqueta:  PRON 	 Etiqueta xpos: pp3fpa00 	 Head:  21 	 Feat:  Case=Acc|Gender=Fem|Number=Plur|Person=3|PrepCase=Npr|PronType=Prs 	 Dep:  obj
# transporta
# Posición:  21  	 Palabra:  transporta 	 Lema:  transportar 	 Etiqueta:  VERB 	 Etiqueta xpos: vmip3s0 	 Head:  15 	 Feat:  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin 	 Dep:  advcl
# de
# Posición:  22  	 Palabra:  de 	 Lema:  de 	 Etiqueta:  ADP 	 Etiqueta xpos: sps00 	 Head:  24 	 Feat:  None 	 Dep:  case
# un
# Posición:  23  	 Palabra:  un 	 Lema:  uno 	 Etiqueta:  DET 	 Etiqueta xpos: di0ms0 	 Head:  24 	 Feat:  Definite=Ind|Gender=Masc|Number=Sing|PronType=Art 	 Dep:  det
# clima
# Posición:  24  	 Palabra:  clima 	 Lema:  clima 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncms000 	 Head:  21 	 Feat:  Gender=Masc|Number=Sing 	 Dep:  obl
# a
# Posición:  25  	 Palabra:  a 	 Lema:  a 	 Etiqueta:  ADP 	 Etiqueta xpos: sps00 	 Head:  26 	 Feat:  None 	 Dep:  case
# otro
# Posición:  26  	 Palabra:  otro 	 Lema:  otro 	 Etiqueta:  PRON 	 Etiqueta xpos: pi0ms000 	 Head:  24 	 Feat:  Gender=Masc|Number=Sing|PronType=Ind 	 Dep:  nmod
# .
# Posición:  27  	 Palabra:  . 	 Lema:  . 	 Etiqueta:  PUNCT 	 Etiqueta xpos: fp 	 Head:  5 	 Feat:  PunctType=Peri 	 Dep:  punct
# f_es:  1
# número de palabras da frase  1 :  0
# En
# Posición:  1  	 Palabra:  En 	 Lema:  en 	 Etiqueta:  ADP 	 Etiqueta xpos: sps00 	 Head:  3 	 Feat:  None 	 Dep:  case
# los
# Posición:  2  	 Palabra:  los 	 Lema:  el 	 Etiqueta:  DET 	 Etiqueta xpos: da0mp0 	 Head:  3 	 Feat:  Definite=Def|Gender=Masc|Number=Plur|PronType=Art 	 Dep:  det
# animales
# Posición:  3  	 Palabra:  animales 	 Lema:  animal 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncmp000 	 Head:  13 	 Feat:  Gender=Masc|Number=Plur 	 Dep:  obl
# ,
# Posición:  4  	 Palabra:  , 	 Lema:  , 	 Etiqueta:  PUNCT 	 Etiqueta xpos: fc 	 Head:  3 	 Feat:  PunctType=Comm 	 Dep:  punct
# el
# Posición:  5  	 Palabra:  el 	 Lema:  el 	 Etiqueta:  DET 	 Etiqueta xpos: da0ms0 	 Head:  7 	 Feat:  Definite=Def|Gender=Masc|Number=Sing|PronType=Art 	 Dep:  det
# creciente
# Posición:  6  	 Palabra:  creciente 	 Lema:  creciente 	 Etiqueta:  ADJ 	 Etiqueta xpos: aq0cs0 	 Head:  7 	 Feat:  Number=Sing 	 Dep:  amod
# uso
# Posición:  7  	 Palabra:  uso 	 Lema:  uso 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncms000 	 Head:  13 	 Feat:  Gender=Masc|Number=Sing 	 Dep:  nsubj
# o
# Posición:  8  	 Palabra:  o 	 Lema:  o 	 Etiqueta:  CCONJ 	 Etiqueta xpos: cc 	 Head:  9 	 Feat:  None 	 Dep:  cc
# desuso
# Posición:  9  	 Palabra:  desuso 	 Lema:  desuso 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncms000 	 Head:  7 	 Feat:  Gender=Masc|Number=Sing 	 Dep:  conj
# de
# Posición:  10  	 Palabra:  de 	 Lema:  de 	 Etiqueta:  ADP 	 Etiqueta xpos: sps00 	 Head:  11 	 Feat:  None 	 Dep:  case
# órganos
# Posición:  11  	 Palabra:  órganos 	 Lema:  órgano 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncmp000 	 Head:  7 	 Feat:  Gender=Masc|Number=Plur 	 Dep:  nmod
# ha
# Posición:  12  	 Palabra:  ha 	 Lema:  haber 	 Etiqueta:  AUX 	 Etiqueta xpos: vaip3s0 	 Head:  13 	 Feat:  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin 	 Dep:  aux
# tenido
# Posición:  13  	 Palabra:  tenido 	 Lema:  tener 	 Etiqueta:  VERB 	 Etiqueta xpos: vmp00sm 	 Head:  0 	 Feat:  Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part 	 Dep:  root
# una
# Posición:  14  	 Palabra:  una 	 Lema:  uno 	 Etiqueta:  DET 	 Etiqueta xpos: di0fs0 	 Head:  15 	 Feat:  Definite=Ind|Gender=Fem|Number=Sing|PronType=Art 	 Dep:  det
# influencia
# Posición:  15  	 Palabra:  influencia 	 Lema:  influencia 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncfs000 	 Head:  13 	 Feat:  Gender=Fem|Number=Sing 	 Dep:  obj
# más
# Posición:  16  	 Palabra:  más 	 Lema:  más 	 Etiqueta:  ADV 	 Etiqueta xpos: rg 	 Head:  17 	 Feat:  Degree=Cmp 	 Dep:  advmod
# marcada
# Posición:  17  	 Palabra:  marcada 	 Lema:  marcado 	 Etiqueta:  ADJ 	 Etiqueta xpos: aq0fsp 	 Head:  15 	 Feat:  Gender=Fem|Number=Sing|VerbForm=Part 	 Dep:  amod
# ;
# Posición:  18  	 Palabra:  ; 	 Lema:  ; 	 Etiqueta:  PUNCT 	 Etiqueta xpos: fx 	 Head:  26 	 Feat:  PunctType=Semi 	 Dep:  punct
# así
# Posición:  19  	 Palabra:  así 	 Lema:  así 	 Etiqueta:  ADV 	 Etiqueta xpos: rg 	 Head:  26 	 Feat:  None 	 Dep:  advmod
# ,
# Posición:  20  	 Palabra:  , 	 Lema:  , 	 Etiqueta:  PUNCT 	 Etiqueta xpos: fc 	 Head:  23 	 Feat:  PunctType=Comm 	 Dep:  punct
# en
# Posición:  21  	 Palabra:  en 	 Lema:  en 	 Etiqueta:  ADP 	 Etiqueta xpos: sps00 	 Head:  23 	 Feat:  None 	 Dep:  case
# el
# Posición:  22  	 Palabra:  el 	 Lema:  el 	 Etiqueta:  DET 	 Etiqueta xpos: da0ms0 	 Head:  23 	 Feat:  Definite=Def|Gender=Masc|Number=Sing|PronType=Art 	 Dep:  det
# pato
# Posición:  23  	 Palabra:  pato 	 Lema:  pato 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncms000 	 Head:  26 	 Feat:  Gender=Masc|Number=Sing 	 Dep:  obl
# doméstico
# Posición:  24  	 Palabra:  doméstico 	 Lema:  doméstico 	 Etiqueta:  ADJ 	 Etiqueta xpos: aq0ms0 	 Head:  23 	 Feat:  Gender=Masc|Number=Sing 	 Dep:  amod
# ,
# Posición:  25  	 Palabra:  , 	 Lema:  , 	 Etiqueta:  PUNCT 	 Etiqueta xpos: fc 	 Head:  23 	 Feat:  PunctType=Comm 	 Dep:  punct
# encuentro
# Posición:  26  	 Palabra:  encuentro 	 Lema:  encontrar 	 Etiqueta:  VERB 	 Etiqueta xpos: vmip3s0 	 Head:  13 	 Feat:  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin 	 Dep:  advcl
# que
# Posición:  27  	 Palabra:  que 	 Lema:  que 	 Etiqueta:  SCONJ 	 Etiqueta xpos: cs 	 Head:  41 	 Feat:  None 	 Dep:  mark
# ,
# Posición:  28  	 Palabra:  , 	 Lema:  , 	 Etiqueta:  PUNCT 	 Etiqueta xpos: fc 	 Head:  34 	 Feat:  PunctType=Comm 	 Dep:  punct
# en
# Posición:  29  	 Palabra:  en 	 Lema:  en 	 Etiqueta:  ADP 	 Etiqueta xpos: sps00 	 Head:  34 	 Feat:  None 	 Dep:  case
# proporción
# Posición:  30  	 Palabra:  proporción 	 Lema:  proporción 	 Etiqueta:  NOUN 	 Etiqueta xpos: s 	 Head:  29 	 Feat:  Gender=Fem|Number=Sing 	 Dep:  fixed
# a
# Posición:  31  	 Palabra:  a 	 Lema:  a 	 Etiqueta:  ADP 	 Etiqueta xpos: None 	 Head:  29 	 Feat:  None 	 Dep:  fixed
# todo
# Posición:  32  	 Palabra:  todo 	 Lema:  todo 	 Etiqueta:  DET 	 Etiqueta xpos: di0ms0 	 Head:  33 	 Feat:  Gender=Masc|Number=Sing|PronType=Tot 	 Dep:  det
# el
# Posición:  33  	 Palabra:  el 	 Lema:  el 	 Etiqueta:  DET 	 Etiqueta xpos: da0ms0 	 Head:  34 	 Feat:  Definite=Def|Gender=Masc|Number=Sing|PronType=Art 	 Dep:  det
# esqueleto
# Posición:  34  	 Palabra:  esqueleto 	 Lema:  esqueleto 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncms000 	 Head:  41 	 Feat:  Gender=Masc|Number=Sing 	 Dep:  obl
# ,
# Posición:  35  	 Palabra:  , 	 Lema:  , 	 Etiqueta:  PUNCT 	 Etiqueta xpos: fc 	 Head:  34 	 Feat:  PunctType=Comm 	 Dep:  punct
# los
# Posición:  36  	 Palabra:  los 	 Lema:  el 	 Etiqueta:  DET 	 Etiqueta xpos: da0mp0 	 Head:  37 	 Feat:  Definite=Def|Gender=Masc|Number=Plur|PronType=Art 	 Dep:  det
# huesos
# Posición:  37  	 Palabra:  huesos 	 Lema:  hueso 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncmp000 	 Head:  41 	 Feat:  Gender=Masc|Number=Plur 	 Dep:  nsubj
# de
# Posición:  38  	 Palabra:  de 	 Lema:  de 	 Etiqueta:  ADP 	 Etiqueta xpos: spcms 	 Head:  40 	 Feat:  None 	 Dep:  case
# el
# Posición:  39  	 Palabra:  el 	 Lema:  el 	 Etiqueta:  DET 	 Etiqueta xpos: None 	 Head:  40 	 Feat:  Definite=Def|Gender=Masc|Number=Sing|PronType=Art 	 Dep:  det
# ala
# Posición:  40  	 Palabra:  ala 	 Lema:  ala 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncfs000 	 Head:  37 	 Feat:  Gender=Fem|Number=Sing 	 Dep:  nmod
# pesan
# Posición:  41  	 Palabra:  pesan 	 Lema:  pesar 	 Etiqueta:  VERB 	 Etiqueta xpos: vmip3p0 	 Head:  26 	 Feat:  Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin 	 Dep:  ccomp
# menos
# Posición:  42  	 Palabra:  menos 	 Lema:  menos 	 Etiqueta:  ADV 	 Etiqueta xpos: rg 	 Head:  41 	 Feat:  Degree=Cmp 	 Dep:  advmod
# y
# Posición:  43  	 Palabra:  y 	 Lema:  y 	 Etiqueta:  CCONJ 	 Etiqueta xpos: cc 	 Head:  45 	 Feat:  None 	 Dep:  cc
# los
# Posición:  44  	 Palabra:  los 	 Lema:  el 	 Etiqueta:  DET 	 Etiqueta xpos: da0mp0 	 Head:  45 	 Feat:  Definite=Def|Gender=Masc|Number=Plur|PronType=Art 	 Dep:  det
# huesos
# Posición:  45  	 Palabra:  huesos 	 Lema:  hueso 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncmp000 	 Head:  41 	 Feat:  Gender=Masc|Number=Plur 	 Dep:  conj
# de
# Posición:  46  	 Palabra:  de 	 Lema:  de 	 Etiqueta:  ADP 	 Etiqueta xpos: sps00 	 Head:  48 	 Feat:  None 	 Dep:  case
# la
# Posición:  47  	 Palabra:  la 	 Lema:  el 	 Etiqueta:  DET 	 Etiqueta xpos: da0fs0 	 Head:  48 	 Feat:  Definite=Def|Gender=Fem|Number=Sing|PronType=Art 	 Dep:  det
# pata
# Posición:  48  	 Palabra:  pata 	 Lema:  pata 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncfs000 	 Head:  45 	 Feat:  Gender=Fem|Number=Sing 	 Dep:  nmod
# más
# Posición:  49  	 Palabra:  más 	 Lema:  más 	 Etiqueta:  ADV 	 Etiqueta xpos: rg 	 Head:  45 	 Feat:  Degree=Cmp 	 Dep:  advmod
# que
# Posición:  50  	 Palabra:  que 	 Lema:  que 	 Etiqueta:  SCONJ 	 Etiqueta xpos: cs 	 Head:  53 	 Feat:  None 	 Dep:  mark
# los
# Posición:  51  	 Palabra:  los 	 Lema:  el 	 Etiqueta:  DET 	 Etiqueta xpos: da0mp0 	 Head:  53 	 Feat:  Definite=Def|Gender=Masc|Number=Plur|PronType=Art 	 Dep:  det
# mismos
# Posición:  52  	 Palabra:  mismos 	 Lema:  mismo 	 Etiqueta:  DET 	 Etiqueta xpos: di0mp0 	 Head:  51 	 Feat:  Gender=Masc|Number=Plur|PronType=Dem 	 Dep:  det
# huesos
# Posición:  53  	 Palabra:  huesos 	 Lema:  hueso 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncmp000 	 Head:  49 	 Feat:  Gender=Masc|Number=Plur 	 Dep:  obl
# de
# Posición:  54  	 Palabra:  de 	 Lema:  de 	 Etiqueta:  ADP 	 Etiqueta xpos: spcms 	 Head:  56 	 Feat:  None 	 Dep:  case
# el
# Posición:  55  	 Palabra:  el 	 Lema:  el 	 Etiqueta:  DET 	 Etiqueta xpos: None 	 Head:  56 	 Feat:  Definite=Def|Gender=Masc|Number=Sing|PronType=Art 	 Dep:  det
# pato
# Posición:  56  	 Palabra:  pato 	 Lema:  pato 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncms000 	 Head:  53 	 Feat:  Gender=Masc|Number=Sing 	 Dep:  nmod
# salvaje
# Posición:  57  	 Palabra:  salvaje 	 Lema:  salvaje 	 Etiqueta:  ADJ 	 Etiqueta xpos: aq0cs0 	 Head:  56 	 Feat:  Number=Sing 	 Dep:  amod
# ,
# Posición:  58  	 Palabra:  , 	 Lema:  , 	 Etiqueta:  PUNCT 	 Etiqueta xpos: fc 	 Head:  63 	 Feat:  PunctType=Comm 	 Dep:  punct
# y
# Posición:  59  	 Palabra:  y 	 Lema:  y 	 Etiqueta:  CCONJ 	 Etiqueta xpos: cc 	 Head:  63 	 Feat:  None 	 Dep:  cc
# este
# Posición:  60  	 Palabra:  este 	 Lema:  este 	 Etiqueta:  DET 	 Etiqueta xpos: dd0ms0 	 Head:  61 	 Feat:  Gender=Masc|Number=Sing|PronType=Dem 	 Dep:  det
# cambio
# Posición:  61  	 Palabra:  cambio 	 Lema:  cambio 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncms000 	 Head:  63 	 Feat:  Gender=Masc|Number=Sing 	 Dep:  nsubj
# puede
# Posición:  62  	 Palabra:  puede 	 Lema:  poder 	 Etiqueta:  AUX 	 Etiqueta xpos: vmip3s0 	 Head:  63 	 Feat:  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin 	 Dep:  aux
# atribuir
# Posición:  63  	 Palabra:  atribuir 	 Lema:  atribuir 	 Etiqueta:  VERB 	 Etiqueta xpos: vmn0000 	 Head:  26 	 Feat:  VerbForm=Inf 	 Dep:  conj
# se
# Posición:  64  	 Palabra:  se 	 Lema:  él 	 Etiqueta:  PRON 	 Etiqueta xpos: None 	 Head:  63 	 Feat:  Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes 	 Dep:  expl:pv
# seguramente
# Posición:  65  	 Palabra:  seguramente 	 Lema:  seguramente 	 Etiqueta:  ADV 	 Etiqueta xpos: rg 	 Head:  63 	 Feat:  None 	 Dep:  advmod
# a
# Posición:  66  	 Palabra:  a 	 Lema:  a 	 Etiqueta:  ADP 	 Etiqueta xpos: sps00 	 Head:  71 	 Feat:  None 	 Dep:  mark
# que
# Posición:  67  	 Palabra:  que 	 Lema:  que 	 Etiqueta:  SCONJ 	 Etiqueta xpos: cs 	 Head:  71 	 Feat:  None 	 Dep:  mark
# el
# Posición:  68  	 Palabra:  el 	 Lema:  el 	 Etiqueta:  DET 	 Etiqueta xpos: da0ms0 	 Head:  69 	 Feat:  Definite=Def|Gender=Masc|Number=Sing|PronType=Art 	 Dep:  det
# pato
# Posición:  69  	 Palabra:  pato 	 Lema:  pato 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncms000 	 Head:  71 	 Feat:  Gender=Masc|Number=Sing 	 Dep:  nsubj
# doméstico
# Posición:  70  	 Palabra:  doméstico 	 Lema:  doméstico 	 Etiqueta:  ADJ 	 Etiqueta xpos: aq0ms0 	 Head:  69 	 Feat:  Gender=Masc|Number=Sing 	 Dep:  amod
# vuela
# Posición:  71  	 Palabra:  vuela 	 Lema:  volar 	 Etiqueta:  VERB 	 Etiqueta xpos: vmip3s0 	 Head:  63 	 Feat:  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin 	 Dep:  ccomp
# mucho
# Posición:  72  	 Palabra:  mucho 	 Lema:  mucho 	 Etiqueta:  PRON 	 Etiqueta xpos: pi0ms000 	 Head:  73 	 Feat:  NumType=Card|PronType=Ind 	 Dep:  advmod
# menos
# Posición:  73  	 Palabra:  menos 	 Lema:  menos 	 Etiqueta:  ADV 	 Etiqueta xpos: rg 	 Head:  71 	 Feat:  Degree=Cmp 	 Dep:  advmod
# y
# Posición:  74  	 Palabra:  y 	 Lema:  y 	 Etiqueta:  CCONJ 	 Etiqueta xpos: cc 	 Head:  75 	 Feat:  None 	 Dep:  cc
# anda
# Posición:  75  	 Palabra:  anda 	 Lema:  andar 	 Etiqueta:  VERB 	 Etiqueta xpos: vmip3s0 	 Head:  71 	 Feat:  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin 	 Dep:  conj
# más
# Posición:  76  	 Palabra:  más 	 Lema:  más 	 Etiqueta:  ADV 	 Etiqueta xpos: rg 	 Head:  75 	 Feat:  Degree=Cmp 	 Dep:  advmod
# que
# Posición:  77  	 Palabra:  que 	 Lema:  que 	 Etiqueta:  SCONJ 	 Etiqueta xpos: cs 	 Head:  79 	 Feat:  None 	 Dep:  mark
# sus
# Posición:  78  	 Palabra:  sus 	 Lema:  su 	 Etiqueta:  DET 	 Etiqueta xpos: dp3cp0 	 Head:  79 	 Feat:  Number=Plur|Person=3|Poss=Yes|PronType=Prs 	 Dep:  det
# progenitores
# Posición:  79  	 Palabra:  progenitores 	 Lema:  progenitor 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncmp000 	 Head:  75 	 Feat:  Gender=Masc|Number=Plur 	 Dep:  obl
# salvajes
# Posición:  80  	 Palabra:  salvajes 	 Lema:  salvaje 	 Etiqueta:  ADJ 	 Etiqueta xpos: aq0cp0 	 Head:  79 	 Feat:  Number=Plur 	 Dep:  amod
# .
# Posición:  81  	 Palabra:  . 	 Lema:  . 	 Etiqueta:  PUNCT 	 Etiqueta xpos: fp 	 Head:  13 	 Feat:  PunctType=Peri 	 Dep:  punct
# f_es:  2
# número de palabras da frase  2 :  0
# El
# Posición:  1  	 Palabra:  El 	 Lema:  el 	 Etiqueta:  DET 	 Etiqueta xpos: da0ms0 	 Head:  5 	 Feat:  Definite=Def|Gender=Masc|Number=Sing|PronType=Art 	 Dep:  det
# grande
# Posición:  2  	 Palabra:  grande 	 Lema:  grande 	 Etiqueta:  ADJ 	 Etiqueta xpos: aq0cs0 	 Head:  5 	 Feat:  Number=Sing 	 Dep:  amod
# y
# Posición:  3  	 Palabra:  y 	 Lema:  y 	 Etiqueta:  CCONJ 	 Etiqueta xpos: cc 	 Head:  4 	 Feat:  None 	 Dep:  cc
# hereditario
# Posición:  4  	 Palabra:  hereditario 	 Lema:  hereditario 	 Etiqueta:  ADJ 	 Etiqueta xpos: aq0ms0 	 Head:  2 	 Feat:  Gender=Masc|Number=Sing 	 Dep:  conj
# desarrollo
# Posición:  5  	 Palabra:  desarrollo 	 Lema:  desarrollo 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncms000 	 Head:  35 	 Feat:  Gender=Masc|Number=Sing 	 Dep:  nsubj
# de
# Posición:  6  	 Palabra:  de 	 Lema:  de 	 Etiqueta:  ADP 	 Etiqueta xpos: sps00 	 Head:  8 	 Feat:  None 	 Dep:  case
# las
# Posición:  7  	 Palabra:  las 	 Lema:  el 	 Etiqueta:  DET 	 Etiqueta xpos: da0fp0 	 Head:  8 	 Feat:  Definite=Def|Gender=Fem|Number=Plur|PronType=Art 	 Dep:  det
# ubres
# Posición:  8  	 Palabra:  ubres 	 Lema:  ubre 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncfp000 	 Head:  5 	 Feat:  Gender=Fem|Number=Plur 	 Dep:  nmod
# en
# Posición:  9  	 Palabra:  en 	 Lema:  en 	 Etiqueta:  ADP 	 Etiqueta xpos: sps00 	 Head:  11 	 Feat:  None 	 Dep:  case
# las
# Posición:  10  	 Palabra:  las 	 Lema:  el 	 Etiqueta:  DET 	 Etiqueta xpos: da0fp0 	 Head:  11 	 Feat:  Definite=Def|Gender=Fem|Number=Plur|PronType=Art 	 Dep:  det
# vacas
# Posición:  11  	 Palabra:  vacas 	 Lema:  vaca 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncfp000 	 Head:  8 	 Feat:  Gender=Fem|Number=Plur 	 Dep:  nmod
# y
# Posición:  12  	 Palabra:  y 	 Lema:  y 	 Etiqueta:  CCONJ 	 Etiqueta xpos: cc 	 Head:  13 	 Feat:  None 	 Dep:  cc
# cabras
# Posición:  13  	 Palabra:  cabras 	 Lema:  cabra 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncfp000 	 Head:  11 	 Feat:  Gender=Fem|Number=Plur 	 Dep:  conj
# en
# Posición:  14  	 Palabra:  en 	 Lema:  en 	 Etiqueta:  ADP 	 Etiqueta xpos: sps00 	 Head:  15 	 Feat:  None 	 Dep:  case
# países
# Posición:  15  	 Palabra:  países 	 Lema:  país 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncmp000 	 Head:  5 	 Feat:  Gender=Masc|Number=Plur 	 Dep:  nmod
# donde
# Posición:  16  	 Palabra:  donde 	 Lema:  donde 	 Etiqueta:  ADV 	 Etiqueta xpos: pr000000 	 Head:  19 	 Feat:  PronType=Rel 	 Dep:  advmod
# son
# Posición:  17  	 Palabra:  son 	 Lema:  ser 	 Etiqueta:  AUX 	 Etiqueta xpos: vsip3p0 	 Head:  19 	 Feat:  Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin 	 Dep:  cop
# habitualmente
# Posición:  18  	 Palabra:  habitualmente 	 Lema:  habitualmente 	 Etiqueta:  ADV 	 Etiqueta xpos: rg 	 Head:  19 	 Feat:  None 	 Dep:  advmod
# ordeñadas
# Posición:  19  	 Palabra:  ordeñadas 	 Lema:  ordeñado 	 Etiqueta:  ADJ 	 Etiqueta xpos: aq0fpp 	 Head:  15 	 Feat:  Gender=Fem|Number=Plur|VerbForm=Part 	 Dep:  acl
# ,
# Posición:  20  	 Palabra:  , 	 Lema:  , 	 Etiqueta:  PUNCT 	 Etiqueta xpos: fc 	 Head:  25 	 Feat:  PunctType=Comm 	 Dep:  punct
# en
# Posición:  21  	 Palabra:  en 	 Lema:  en 	 Etiqueta:  ADP 	 Etiqueta xpos: sps00 	 Head:  25 	 Feat:  None 	 Dep:  case
# comparación
# Posición:  22  	 Palabra:  comparación 	 Lema:  comparación 	 Etiqueta:  NOUN 	 Etiqueta xpos: None 	 Head:  21 	 Feat:  Gender=Fem|Number=Sing 	 Dep:  fixed
# con
# Posición:  23  	 Palabra:  con 	 Lema:  con 	 Etiqueta:  ADP 	 Etiqueta xpos: None 	 Head:  21 	 Feat:  None 	 Dep:  fixed
# estos
# Posición:  24  	 Palabra:  estos 	 Lema:  este 	 Etiqueta:  DET 	 Etiqueta xpos: dd0mp0 	 Head:  25 	 Feat:  Gender=Masc|Number=Plur|PronType=Dem 	 Dep:  det
# órganos
# Posición:  25  	 Palabra:  órganos 	 Lema:  órgano 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncmp000 	 Head:  19 	 Feat:  Gender=Masc|Number=Plur 	 Dep:  obl
# en
# Posición:  26  	 Palabra:  en 	 Lema:  en 	 Etiqueta:  ADP 	 Etiqueta xpos: sps00 	 Head:  28 	 Feat:  None 	 Dep:  case
# otros
# Posición:  27  	 Palabra:  otros 	 Lema:  otro 	 Etiqueta:  DET 	 Etiqueta xpos: di0mp0 	 Head:  28 	 Feat:  Gender=Masc|Number=Plur|PronType=Ind 	 Dep:  det
# países
# Posición:  28  	 Palabra:  países 	 Lema:  país 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncmp000 	 Head:  25 	 Feat:  Gender=Masc|Number=Plur 	 Dep:  nmod
# ,
# Posición:  29  	 Palabra:  , 	 Lema:  , 	 Etiqueta:  PUNCT 	 Etiqueta xpos: fc 	 Head:  25 	 Feat:  PunctType=Comm 	 Dep:  punct
# es
# Posición:  30  	 Palabra:  es 	 Lema:  ser 	 Etiqueta:  AUX 	 Etiqueta xpos: vsip3s0 	 Head:  35 	 Feat:  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin 	 Dep:  cop
# ,
# Posición:  31  	 Palabra:  , 	 Lema:  , 	 Etiqueta:  PUNCT 	 Etiqueta xpos: fc 	 Head:  32 	 Feat:  PunctType=Comm 	 Dep:  punct
# probablemente
# Posición:  32  	 Palabra:  probablemente 	 Lema:  probablemente 	 Etiqueta:  ADV 	 Etiqueta xpos: rg 	 Head:  35 	 Feat:  None 	 Dep:  advmod
# ,
# Posición:  33  	 Palabra:  , 	 Lema:  , 	 Etiqueta:  PUNCT 	 Etiqueta xpos: fc 	 Head:  32 	 Feat:  PunctType=Comm 	 Dep:  punct
# otro
# Posición:  34  	 Palabra:  otro 	 Lema:  otro 	 Etiqueta:  DET 	 Etiqueta xpos: di0ms0 	 Head:  35 	 Feat:  Gender=Masc|Number=Sing|PronType=Ind 	 Dep:  det
# ejemplo
# Posición:  35  	 Palabra:  ejemplo 	 Lema:  ejemplo 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncms000 	 Head:  0 	 Feat:  Gender=Masc|Number=Sing 	 Dep:  root
# de
# Posición:  36  	 Palabra:  de 	 Lema:  de 	 Etiqueta:  ADP 	 Etiqueta xpos: sps00 	 Head:  38 	 Feat:  None 	 Dep:  case
# los
# Posición:  37  	 Palabra:  los 	 Lema:  el 	 Etiqueta:  DET 	 Etiqueta xpos: da0mp0 	 Head:  38 	 Feat:  Definite=Def|Gender=Masc|Number=Plur|PronType=Art 	 Dep:  det
# efectos
# Posición:  38  	 Palabra:  efectos 	 Lema:  efecto 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncmp000 	 Head:  35 	 Feat:  Gender=Masc|Number=Plur 	 Dep:  nmod
# de
# Posición:  39  	 Palabra:  de 	 Lema:  de 	 Etiqueta:  ADP 	 Etiqueta xpos: spcms 	 Head:  41 	 Feat:  None 	 Dep:  case
# el
# Posición:  40  	 Palabra:  el 	 Lema:  el 	 Etiqueta:  DET 	 Etiqueta xpos: None 	 Head:  41 	 Feat:  Definite=Def|Gender=Masc|Number=Sing|PronType=Art 	 Dep:  det
# uso
# Posición:  41  	 Palabra:  uso 	 Lema:  uso 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncms000 	 Head:  38 	 Feat:  Gender=Masc|Number=Sing 	 Dep:  nmod
# .
# Posición:  42  	 Palabra:  . 	 Lema:  . 	 Etiqueta:  PUNCT 	 Etiqueta xpos: fp 	 Head:  35 	 Feat:  PunctType=Peri 	 Dep:  punct
# f_es:  3
# número de palabras da frase  3 :  0
# No
# Posición:  1  	 Palabra:  No 	 Lema:  no 	 Etiqueta:  ADV 	 Etiqueta xpos: rn 	 Head:  3 	 Feat:  Polarity=Neg 	 Dep:  advmod
# puede
# Posición:  2  	 Palabra:  puede 	 Lema:  poder 	 Etiqueta:  AUX 	 Etiqueta xpos: vmip3s0 	 Head:  3 	 Feat:  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin 	 Dep:  aux
# citar
# Posición:  3  	 Palabra:  citar 	 Lema:  citar 	 Etiqueta:  VERB 	 Etiqueta xpos: vmn0000 	 Head:  0 	 Feat:  VerbForm=Inf 	 Dep:  root
# se
# Posición:  4  	 Palabra:  se 	 Lema:  él 	 Etiqueta:  PRON 	 Etiqueta xpos: None 	 Head:  3 	 Feat:  Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes 	 Dep:  expl:pv
# un
# Posición:  5  	 Palabra:  un 	 Lema:  uno 	 Etiqueta:  DET 	 Etiqueta xpos: di0ms0 	 Head:  6 	 Feat:  Definite=Ind|Gender=Masc|Number=Sing|PronType=Art 	 Dep:  det
# animal
# Posición:  6  	 Palabra:  animal 	 Lema:  animal 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncms000 	 Head:  3 	 Feat:  Gender=Masc|Number=Sing 	 Dep:  nsubj
# doméstico
# Posición:  7  	 Palabra:  doméstico 	 Lema:  doméstico 	 Etiqueta:  ADJ 	 Etiqueta xpos: aq0ms0 	 Head:  6 	 Feat:  Gender=Masc|Number=Sing 	 Dep:  amod
# que
# Posición:  8  	 Palabra:  que 	 Lema:  que 	 Etiqueta:  PRON 	 Etiqueta xpos: pr0cn000 	 Head:  10 	 Feat:  PronType=Rel 	 Dep:  nsubj
# no
# Posición:  9  	 Palabra:  no 	 Lema:  no 	 Etiqueta:  ADV 	 Etiqueta xpos: rn 	 Head:  10 	 Feat:  Polarity=Neg 	 Dep:  advmod
# tenga
# Posición:  10  	 Palabra:  tenga 	 Lema:  tener 	 Etiqueta:  VERB 	 Etiqueta xpos: vmsp3s0 	 Head:  6 	 Feat:  Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin 	 Dep:  acl
# en
# Posición:  11  	 Palabra:  en 	 Lema:  en 	 Etiqueta:  ADP 	 Etiqueta xpos: sps00 	 Head:  13 	 Feat:  None 	 Dep:  case
# algún
# Posición:  12  	 Palabra:  algún 	 Lema:  alguno 	 Etiqueta:  DET 	 Etiqueta xpos: di0ms0 	 Head:  13 	 Feat:  Gender=Masc|Number=Sing|PronType=Ind 	 Dep:  det
# país
# Posición:  13  	 Palabra:  país 	 Lema:  país 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncms000 	 Head:  10 	 Feat:  Gender=Masc|Number=Sing 	 Dep:  obl
# las
# Posición:  14  	 Palabra:  las 	 Lema:  el 	 Etiqueta:  DET 	 Etiqueta xpos: da0fp0 	 Head:  15 	 Feat:  Definite=Def|Gender=Fem|Number=Plur|PronType=Art 	 Dep:  det
# orejas
# Posición:  15  	 Palabra:  orejas 	 Lema:  oreja 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncfp000 	 Head:  10 	 Feat:  Gender=Fem|Number=Plur 	 Dep:  obj
# caídas
# Posición:  16  	 Palabra:  caídas 	 Lema:  caído 	 Etiqueta:  ADJ 	 Etiqueta xpos: aq0fpp 	 Head:  15 	 Feat:  Gender=Fem|Number=Plur|VerbForm=Part 	 Dep:  amod
# ,
# Posición:  17  	 Palabra:  , 	 Lema:  , 	 Etiqueta:  PUNCT 	 Etiqueta xpos: fc 	 Head:  19 	 Feat:  PunctType=Comm 	 Dep:  punct
# y
# Posición:  18  	 Palabra:  y 	 Lema:  y 	 Etiqueta:  CCONJ 	 Etiqueta xpos: cc 	 Head:  19 	 Feat:  None 	 Dep:  cc
# parece
# Posición:  19  	 Palabra:  parece 	 Lema:  parecer 	 Etiqueta:  VERB 	 Etiqueta xpos: vmip3s0 	 Head:  3 	 Feat:  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin 	 Dep:  conj
# probable
# Posición:  20  	 Palabra:  probable 	 Lema:  probable 	 Etiqueta:  ADJ 	 Etiqueta xpos: aq0cs0 	 Head:  19 	 Feat:  Number=Sing 	 Dep:  xcomp
# la
# Posición:  21  	 Palabra:  la 	 Lema:  el 	 Etiqueta:  DET 	 Etiqueta xpos: da0fs0 	 Head:  22 	 Feat:  Definite=Def|Gender=Fem|Number=Sing|PronType=Art 	 Dep:  det
# opinión
# Posición:  22  	 Palabra:  opinión 	 Lema:  opinión 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncfs000 	 Head:  19 	 Feat:  Gender=Fem|Number=Sing 	 Dep:  nsubj
# ,
# Posición:  23  	 Palabra:  , 	 Lema:  , 	 Etiqueta:  PUNCT 	 Etiqueta xpos: fc 	 Head:  27 	 Feat:  PunctType=Comm 	 Dep:  punct
# que
# Posición:  24  	 Palabra:  que 	 Lema:  que 	 Etiqueta:  PRON 	 Etiqueta xpos: pr0cn000 	 Head:  27 	 Feat:  PronType=Rel 	 Dep:  nsubj
# se
# Posición:  25  	 Palabra:  se 	 Lema:  él 	 Etiqueta:  PRON 	 Etiqueta xpos: p0000000 	 Head:  27 	 Feat:  Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes 	 Dep:  expl:pv
# ha
# Posición:  26  	 Palabra:  ha 	 Lema:  haber 	 Etiqueta:  AUX 	 Etiqueta xpos: vaip3s0 	 Head:  27 	 Feat:  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin 	 Dep:  aux
# indicado
# Posición:  27  	 Palabra:  indicado 	 Lema:  indicar 	 Etiqueta:  VERB 	 Etiqueta xpos: vmp00sm 	 Head:  22 	 Feat:  Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part 	 Dep:  acl
# ,
# Posición:  28  	 Palabra:  , 	 Lema:  , 	 Etiqueta:  PUNCT 	 Etiqueta xpos: fc 	 Head:  37 	 Feat:  PunctType=Comm 	 Dep:  punct
# de
# Posición:  29  	 Palabra:  de 	 Lema:  de 	 Etiqueta:  ADP 	 Etiqueta xpos: sps00 	 Head:  37 	 Feat:  None 	 Dep:  mark
# que
# Posición:  30  	 Palabra:  que 	 Lema:  que 	 Etiqueta:  SCONJ 	 Etiqueta xpos: cs 	 Head:  37 	 Feat:  None 	 Dep:  mark
# el
# Posición:  31  	 Palabra:  el 	 Lema:  el 	 Etiqueta:  DET 	 Etiqueta xpos: da0ms0 	 Head:  32 	 Feat:  Definite=Def|Gender=Masc|Number=Sing|PronType=Art 	 Dep:  det
# tener
# Posición:  32  	 Palabra:  tener 	 Lema:  tener 	 Etiqueta:  VERB 	 Etiqueta xpos: vmn0000 	 Head:  37 	 Feat:  VerbForm=Inf 	 Dep:  csubj
# las
# Posición:  33  	 Palabra:  las 	 Lema:  el 	 Etiqueta:  DET 	 Etiqueta xpos: da0fp0 	 Head:  34 	 Feat:  Definite=Def|Gender=Fem|Number=Plur|PronType=Art 	 Dep:  det
# orejas
# Posición:  34  	 Palabra:  orejas 	 Lema:  oreja 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncfp000 	 Head:  32 	 Feat:  Gender=Fem|Number=Plur 	 Dep:  obj
# caídas
# Posición:  35  	 Palabra:  caídas 	 Lema:  caído 	 Etiqueta:  ADJ 	 Etiqueta xpos: aq0fpp 	 Head:  34 	 Feat:  Gender=Fem|Number=Plur|VerbForm=Part 	 Dep:  amod
# se
# Posición:  36  	 Palabra:  se 	 Lema:  él 	 Etiqueta:  PRON 	 Etiqueta xpos: p0300000 	 Head:  37 	 Feat:  Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes 	 Dep:  expl:pv
# debe
# Posición:  37  	 Palabra:  debe 	 Lema:  deber 	 Etiqueta:  VERB 	 Etiqueta xpos: vmip3s0 	 Head:  22 	 Feat:  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin 	 Dep:  acl
# a
# Posición:  38  	 Palabra:  a 	 Lema:  a 	 Etiqueta:  ADP 	 Etiqueta xpos: spcms 	 Head:  40 	 Feat:  None 	 Dep:  case
# el
# Posición:  39  	 Palabra:  el 	 Lema:  el 	 Etiqueta:  DET 	 Etiqueta xpos: None 	 Head:  40 	 Feat:  Definite=Def|Gender=Masc|Number=Sing|PronType=Art 	 Dep:  det
# desuso
# Posición:  40  	 Palabra:  desuso 	 Lema:  desuso 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncms000 	 Head:  37 	 Feat:  Gender=Masc|Number=Sing 	 Dep:  obl:arg
# de
# Posición:  41  	 Palabra:  de 	 Lema:  de 	 Etiqueta:  ADP 	 Etiqueta xpos: sps00 	 Head:  43 	 Feat:  None 	 Dep:  case
# los
# Posición:  42  	 Palabra:  los 	 Lema:  el 	 Etiqueta:  DET 	 Etiqueta xpos: da0mp0 	 Head:  43 	 Feat:  Definite=Def|Gender=Masc|Number=Plur|PronType=Art 	 Dep:  det
# músculos
# Posición:  43  	 Palabra:  músculos 	 Lema:  músculo 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncmp000 	 Head:  40 	 Feat:  Gender=Masc|Number=Plur 	 Dep:  nmod
# de
# Posición:  44  	 Palabra:  de 	 Lema:  de 	 Etiqueta:  ADP 	 Etiqueta xpos: sps00 	 Head:  46 	 Feat:  None 	 Dep:  case
# la
# Posición:  45  	 Palabra:  la 	 Lema:  el 	 Etiqueta:  DET 	 Etiqueta xpos: da0fs0 	 Head:  46 	 Feat:  Definite=Def|Gender=Fem|Number=Sing|PronType=Art 	 Dep:  det
# oreja
# Posición:  46  	 Palabra:  oreja 	 Lema:  oreja 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncfs000 	 Head:  43 	 Feat:  Gender=Fem|Number=Sing 	 Dep:  nmod
# ,
# Posición:  47  	 Palabra:  , 	 Lema:  , 	 Etiqueta:  PUNCT 	 Etiqueta xpos: fc 	 Head:  54 	 Feat:  PunctType=Comm 	 Dep:  punct
# porque
# Posición:  48  	 Palabra:  porque 	 Lema:  porque 	 Etiqueta:  SCONJ 	 Etiqueta xpos: cs 	 Head:  54 	 Feat:  None 	 Dep:  mark
# estos
# Posición:  49  	 Palabra:  estos 	 Lema:  este 	 Etiqueta:  DET 	 Etiqueta xpos: dd0mp0 	 Head:  50 	 Feat:  Gender=Masc|Number=Plur|PronType=Dem 	 Dep:  det
# animales
# Posición:  50  	 Palabra:  animales 	 Lema:  animal 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncmp000 	 Head:  54 	 Feat:  Gender=Masc|Number=Plur 	 Dep:  nsubj
# raras
# Posición:  51  	 Palabra:  raras 	 Lema:  raro 	 Etiqueta:  ADJ 	 Etiqueta xpos: aq0fp0 	 Head:  52 	 Feat:  Gender=Fem|Number=Plur 	 Dep:  amod
# veces
# Posición:  52  	 Palabra:  veces 	 Lema:  vez 	 Etiqueta:  NOUN 	 Etiqueta xpos: ncfp000 	 Head:  54 	 Feat:  Gender=Fem|Number=Plur 	 Dep:  obl
# se
# Posición:  53  	 Palabra:  se 	 Lema:  él 	 Etiqueta:  PRON 	 Etiqueta xpos: p0300000 	 Head:  54 	 Feat:  Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes 	 Dep:  expl:pv
# sienten
# Posición:  54  	 Palabra:  sienten 	 Lema:  sentir 	 Etiqueta:  VERB 	 Etiqueta xpos: vmip3p0 	 Head:  37 	 Feat:  Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin 	 Dep:  advcl
# muy
# Posición:  55  	 Palabra:  muy 	 Lema:  mucho 	 Etiqueta:  ADV 	 Etiqueta xpos: rg 	 Head:  56 	 Feat:  None 	 Dep:  advmod
# alarmados
# Posición:  56  	 Palabra:  alarmados 	 Lema:  alarmado 	 Etiqueta:  ADJ 	 Etiqueta xpos: aq0mpp 	 Head:  54 	 Feat:  Gender=Masc|Number=Plur|VerbForm=Part 	 Dep:  obj
# .
# Posición:  57  	 Palabra:  . 	 Lema:  . 	 Etiqueta:  PUNCT 	 Etiqueta xpos: fp 	 Head:  3 	 Feat:  PunctType=Peri 	 Dep:  punct
# [25, 73, 37, 52]
# Dicionario léxico en castelán, número de tipos:  13
# Dicionario léxico en castelán:  {'DET': 39, 'NOUN': 44, 'ADP': 27, 'VERB': 16, 'ADJ': 16, 'PUNCT': 20, 'SCONJ': 8, 'PRON': 11, 'CCONJ': 7, 'AUX': 6, 'ADV': 13}
# Total de palabras do texto en castelán:  187
# Número de caracteres totais do texto en castelán:  1032

# %% [markdown]
# Velaquí temos os resultados da análise do texto en castelán

# %%
# Resultados a análises solicitadas

print("\n RESULTADOS:")
print(" Lonxitude media das frases (texto en castelán): ", lmf_es)
print(" Diversidade lexical (TTR): ", ttr_es )
print(" Lonxitude media das palabras (texto en castelán): ", nmc_es)
print(" Índice de dificultade de lectura (texto en castelán)", dific_es)
# Out:
#  RESULTADOS:
#  Lonxitude media das frases (texto en castelán):  46.75
#  Diversidade lexical (TTR):  0.06951871657754011
#  Lonxitude media das palabras (texto en castelán):  5.518716577540107
#  Índice de dificultade de lectura (texto en castelán) 0.09090909090909091

# %% [markdown]
# Finalmente imos comparar os resultados:

# %%
#Cálculos
lmf_comp = lmf_gl/lmf_es
ttr_comp = ttr_gl/ttr_es
nmc_comp = nmc_gl/nmc_es
dific_comp = dific_gl/dific_es
#Visualización de resultados
print("\n COMPARATIVA DE RESULTADOS:")
print("\n Valor superior a 1, maior en galego. Valor inferior a 1, maior en castelán")
print(" Relación entre lonxitudes medias de frase: ", lmf_comp)
print(" Relación entre diversidades lexicais (TTR): ", ttr_comp)
print(" Relación entre lonxitudes medias de palabra: ", nmc_comp)
print(" Relación entre dificultades de lectura: ", dific_comp)

if lmf_comp > 1:
  print(" Lonxitude media de frase maior en galego")
elif lmf_comp == 1:
  print(" Lonxitudes medias de frase iguais en ambos idiomas")
else:
  print (" Lonxitude media de frase maior en castelán")

if ttr_comp > 1:
  print(" Diversidade léxica (TTR) maior en galego")
elif ttr_comp == 1:
  print(" Diversidades léxicas iguais en ambos idiomas")
else:
  print (" Diversidade léxica de frase maior en castelán")

if nmc_comp > 1:
  print(" Lonxitude media de palabra maior en galego")
elif nmc_comp == 1:
  print(" Lonxitudes medias de palabra iguais en ambos idiomas")
else:
  print (" Lonxitude media de palabra maior en castelán")

if dific_comp > 1:
  print(" Dificultade de lectura maior en galego")
elif dific_comp == 1:
  print(" Dificultades de lectura iguais en ambos idiomas")
else:
  print (" Dificultade de lectura maior en castelán")
# Out:
#  COMPARATIVA DE RESULTADOS:
#
#  Valor superior a 1, maior en galego. Valor inferior a 1, maior en castelán
#  Relación entre lonxitudes medias de frase:  0.21899668958492485
#  Relación entre diversidades lexicais (TTR):  0.8697674418604651
#  Relación entre lonxitudes medias de palabra:  0.3084640346133045
#  Relación entre dificultades de lectura:  2.5384615384615383
#  Lonxitude media de frase maior en castelán
#  Diversidade léxica de frase maior en castelán
#  Lonxitude media de palabra maior en castelán
#  Dificultade de lectura maior en galego
